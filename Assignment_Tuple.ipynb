# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasp9090/Tuple_Experiments/blob/main/Assignment_Tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Write a Python program to create a tuple and print its elements.
t1=tuple((10, 20, 30, 40))
t1
# Out:
# (10, 20, 30, 40)

# %%
#2. Write a Python program to find the length of a tuple.
t2 = (1, 2, 3, 4, 5)
print("Length=",len(t2))
# Out:
# Length= 5

# %%
#3. Write a Python program to count the occurrences of an element in a tuple
t3 = (1, 2, 2, 3, 2, 4)
print(" Occurrences of 2 =",t3.count(2))
# Out:
#  Occurrences of 2 = 3

# %%
#4. Write a Python program to find the index of an element in a tuple
t4=(10,20,30,40)
print("Index=",t4.index(30))
# Out:
# Index= 2

# %%
#5. Write a Python program to convert a tuple into a list and a list into a tuple.

t_1 = (1, 2, 3)
l = [4, 5, 6]

print("Tuple to List =", list(t_1))
print("List to Tuple =", tuple(l))
# Out:
# Tuple to List = [1, 2, 3]
# List to Tuple = (4, 5, 6)

# %%
# 6. Write a Python program to find the maximum and minimum values in a tuple.
t6=(8, 3, 15, 1, 9)
print(" Maximum",max(t6))
print(" Minimum",min(t6))
# Out:
#  Maximum 15
#  Minimum 1

# %%
#7. Write a Python program to slice a tuple and print specific elements.
t7= (10, 20, 30, 40, 50)
t7[1:4]
# Out:
# (20, 30, 40)

# %%
#8. Write a Python program to concatenate two tuples.
t_8 = (1, 2, 3)
t8 = (4, 5)
t_8 + t8
# Out:
# (1, 2, 3, 4, 5)

# %%
#9. Write a Python program to check whether an element exists in a tuple.
t9=(10,20,30)
num=20
#for num in t9:
if num in t9:
    print("20 exists in the tuple.")
else:
  print("Number Is Not exist")
# Out:
# 20 exists in the tuple.

# %%
#10. Write a Python program to create a tuple with repeated elements.
t10=(5,)*4
t10
# Out:
# (5, 5, 5, 5)

# %%
#11. Write a Python program to unpack a tuple into separate variables
t11=(101, "Amit", 85.5)
Roll,Name,Marks=t11
print('Roll=',Roll)
print("Name=",Name)
print("Marks=",Marks)
# Out:
# Roll= 101
# Name= Amit
# Marks= 85.5

# %%
#12. Write a Python program to sort tuple elements and display the result
t12=(5,2,8,1,4)
result=sorted(t12)
print(tuple(result))
# Out:
# (1, 2, 4, 5, 8)

# %%
# 13. Write a Python program to remove duplicate values from a tuple.
t13=(1, 2, 2, 3, 1, 4)
tuple(set(t13))
# Out:
# (1, 2, 3, 4)

# %%
#14. Write a Python program to create a nested tuple and access its inner elements.
t14=(1,2,(10,20,30))
print("Inner tuple =",t14[2])
print("Second inner element =",t14[2][1])
# Out:
# Inner tuple = (10, 20, 30)
# Second inner element = 20

# %%
# 15. Write a Python program to swap two tuples.
ta = (1, 2)
tb = (3, 4)
ta,tb=tb,ta
print("Tuple A:",ta)
print("Tuple B:",tb)
# Out:
# Tuple A: (3, 4)
# Tuple B: (1, 2)

# %%
# 16. Write a Python program to find the sum of numeric elements in a tuple.
t16=(10,20,30,40)
print("Sum=",sum(t16))
# Out:
# Sum= 100
